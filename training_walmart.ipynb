# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
# %matplotlib inline 
import warnings

warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("best_brand_suppliers_per_product.csv")

# %%
df.head()
# Out:
#   product_id product_name supplier_id            supplier_name   region  \
# 0         P1   Dawat Rice          S8          Martin-Mcdowell   Mumbai
# 1         P1   Dawat Rice          S5           Nelson-Ramirez   Mumbai
# 2         P1   Dawat Rice          S3  Bell, Gardner and Brown  Kolkata
# 3         P1   Dawat Rice          S3  Bell, Gardner and Brown   Mumbai
# 4         P1   Dawat Rice          S9             Thornton Ltd  Kolkata
#
#   purchase_date  units_purchased  unit_cost  total_cost  delivery_time_days  \
# 0    2025-01-11              971      16.55    16070.05                   6
# 1    2025-03-14              689      38.80    26733.20                   7
# 2    2025-04-29              814      37.38    30427.32                   7
# 3    2024-12-30              990      23.38    23146.20                   3
# 4    2025-06-02              406      64.58    26219.48                   2
#
#    qc_pass_rate  customer_rating_avg  damaged_on_arrival  complaint_count  \
# 0          0.97                 4.41                0.00                2
# 1          0.98                 3.78                0.00                6
# 2          0.93                 3.86                0.01                5
# 3          0.91                 3.17                0.05                9
# 4          0.85                 3.20                0.03                2
#
#    units_returned  return_rate  supplier_score  supplier_rank
# 0              62        0.064       94.148153            1.0
# 1              25        0.036       88.189929            2.0
# 2              35        0.043       87.199128            3.0
# 3              84        0.085       86.214753            4.0
# 4              16        0.039       76.833344            5.0

# %%
x=df.drop(['product_id','product_name','supplier_id','purchase_date','supplier_name','supplier_rank','supplier_score','region'],axis=1)

# %%
x
# Out:
#      units_purchased  unit_cost  total_cost  delivery_time_days  qc_pass_rate  \
# 0                971      16.55    16070.05                   6          0.97
# 1                689      38.80    26733.20                   7          0.98
# 2                814      37.38    30427.32                   7          0.93
# 3                990      23.38    23146.20                   3          0.91
# 4                406      64.58    26219.48                   2          0.85
# ..               ...        ...         ...                 ...           ...
# 183              923      19.16    17684.68                   8          0.87
# 184              435      30.80    13398.00                   2          0.95
# 185              324      59.20    19180.80                   6          0.88
# 186              699      59.67    41709.33                   7          0.93
# 187              457      75.34    34430.38                   2          0.98
#
#      customer_rating_avg  damaged_on_arrival  complaint_count  units_returned  \
# 0                   4.41                0.00                2              62
# 1                   3.78                0.00                6              25
# 2                   3.86                0.01                5              35
# 3                   3.17                0.05                9              84
# 4                   3.20                0.03                2              16
# ..                   ...                 ...              ...             ...
# 183                 3.49                0.01                4              86
# 184                 3.04                0.01                0              31
# 185                 4.94                0.04                0              14
# 186                 4.75                0.02               10              62
# 187                 4.77                0.04                3              23
#
#      return_rate
# 0          0.064
# 1          0.036
# 2          0.043
# 3          0.085
# 4          0.039
# ..           ...
# 183        0.093
# 184        0.071
# 185        0.043
# 186        0.089
# 187        0.050
#
# [188 rows x 10 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
Scaler=MinMaxScaler()

# %%
x_scaled_df=Scaler.fit_transform(x)

# %%
x_scaled_df
# Out:
# array([[0.9708193 , 0.07059233, 0.15801957, ..., 0.2       , 0.71264368,
#         0.64      ],
#        [0.65432099, 0.32850354, 0.272204  , ..., 0.6       , 0.28735632,
#         0.36      ],
#        [0.79461279, 0.31204358, 0.31176182, ..., 0.5       , 0.40229885,
#         0.43      ],
#        ...,
#        [0.24466891, 0.56497044, 0.19133048, ..., 0.        , 0.16091954,
#         0.43      ],
#        [0.66554433, 0.57041845, 0.43257319, ..., 1.        , 0.71264368,
#         0.89      ],
#        [0.39393939, 0.75205749, 0.35462786, ..., 0.3       , 0.26436782,
#         0.5       ]], shape=(188, 10))

# %%
pd.DataFrame(x_scaled_df,columns=x.columns)
# Out:
#      units_purchased  unit_cost  total_cost  delivery_time_days  qc_pass_rate  \
# 0           0.970819   0.070592    0.158020            0.555556      0.800000
# 1           0.654321   0.328504    0.272204            0.666667      0.866667
# 2           0.794613   0.312044    0.311762            0.666667      0.533333
# 3           0.992144   0.149762    0.233793            0.222222      0.400000
# 4           0.336700   0.627333    0.266703            0.111111      0.000000
# ..               ...        ...         ...                 ...           ...
# 183         0.916947   0.100846    0.175310            0.777778      0.133333
# 184         0.369248   0.235771    0.129406            0.111111      0.666667
# 185         0.244669   0.564970    0.191330            0.555556      0.200000
# 186         0.665544   0.570418    0.432573            0.666667      0.533333
# 187         0.393939   0.752057    0.354628            0.111111      0.866667
#
#      customer_rating_avg  damaged_on_arrival  complaint_count  units_returned  \
# 0               0.709184                 0.0              0.2        0.712644
# 1               0.387755                 0.0              0.6        0.287356
# 2               0.428571                 0.2              0.5        0.402299
# 3               0.076531                 1.0              0.9        0.965517
# 4               0.091837                 0.6              0.2        0.183908
# ..                   ...                 ...              ...             ...
# 183             0.239796                 0.2              0.4        0.988506
# 184             0.010204                 0.2              0.0        0.356322
# 185             0.979592                 0.8              0.0        0.160920
# 186             0.882653                 0.4              1.0        0.712644
# 187             0.892857                 0.8              0.3        0.264368
#
#      return_rate
# 0           0.64
# 1           0.36
# 2           0.43
# 3           0.85
# 4           0.39
# ..           ...
# 183         0.93
# 184         0.71
# 185         0.43
# 186         0.89
# 187         0.50
#
# [188 rows x 10 columns]

# %%
y=df[["supplier_rank","supplier_score"]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.30)

# %%
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
##Create a Function to Evaluate Model
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
print("x_train:", x_train.shape)
print("y_train:", y_train.shape)
print("x_test:", x_test.shape)
print("y_test:", y_test.shape)
# Out:
# x_train: (131, 10)
# y_train: (131, 2)
# x_test: (57, 10)
# y_test: (57, 2)

# %%
## Beginning Model Training

models = {
    "Linear Regression": MultiOutputRegressor(LinearRegression()),
    "Lasso": MultiOutputRegressor(Lasso()),
    "Ridge": MultiOutputRegressor(Ridge()),
    "K-Neighbors Regressor": MultiOutputRegressor(KNeighborsRegressor()),
    "Decision Tree": MultiOutputRegressor(DecisionTreeRegressor()),
    "Random Forest Regressor": MultiOutputRegressor(RandomForestRegressor()),
    "AdaBoost Regressor": MultiOutputRegressor(AdaBoostRegressor()),
    "Gradient Boost Regressor": MultiOutputRegressor(GradientBoostingRegressor())
}
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(x_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)
    
    # Evaluate Train and Test dataset
    model_train_mae , model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)

    model_test_mae , model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    
    print(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- R2 Score: {:.4f}".format(model_train_r2))

    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- R2 Score: {:.4f}".format(model_test_r2))
    
    print('='*35)
    print('\n')
# Out:
# Linear Regression
# Model performance for Training set
# - Root Mean Squared Error: 1.1774
# - Mean Absolute Error: 0.6691
# - R2 Score: 0.8308
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 1.1740
# - Mean Absolute Error: 0.6853
# - R2 Score: 0.8202
# ===================================
#
#
# Lasso
# Model performance for Training set
# - Root Mean Squared Error: 1.9355
# - Mean Absolute Error: 1.6132
# - R2 Score: 0.7301
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 2.2051
# - Mean Absolute Error: 1.8683
# - R2 Score: 0.6629
# ===================================
#
#
# Ridge
# Model performance for Training set
# - Root Mean Squared Error: 1.3660
# - Mean Absolute Error: 1.0628
# - R2 Score: 0.8071
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 1.4248
# - Mean Absolute Error: 1.1446
# - R2 Score: 0.7850
# ===================================
#
#
# K-Neighbors Regressor
# Model performance for Training set
# - Root Mean Squared Error: 2.8279
# - Mean Absolute Error: 2.1855
# - R2 Score: 0.5565
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 3.1427
# - Mean Absolute Error: 2.3716
# - R2 Score: 0.5472
# ===================================
#
#
# Decision Tree
# Model performance for Training set
# - Root Mean Squared Error: 0.0000
# - Mean Absolute Error: 0.0000
# - R2 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 2.5063
# - Mean Absolute Error: 1.9743
# - R2 Score: 0.4151
# ===================================
#
#
# Random Forest Regressor
# Model performance for Training set
# - Root Mean Squared Error: 0.6473
# - Mean Absolute Error: 0.5079
# - R2 Score: 0.9656
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 1.7089
# - Mean Absolute Error: 1.3589
# - R2 Score: 0.7474
# ===================================
#
#
# AdaBoost Regressor
# Model performance for Training set
# - Root Mean Squared Error: 1.0855
# - Mean Absolute Error: 0.9298
# - R2 Score: 0.8984
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 1.8189
# - Mean Absolute Error: 1.4888
# - R2 Score: 0.7295
# ===================================
#
#
# Gradient Boost Regressor
# Model performance for Training set
# - Root Mean Squared Error: 0.3313
# - Mean Absolute Error: 0.2264
# - R2 Score: 0.9874
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 1.5614
# - Mean Absolute Error: 1.2113
# - R2 Score: 0.7453
# ===================================

# %%
base_models = [
    DecisionTreeRegressor(max_depth=3),
    DecisionTreeRegressor(max_depth=5),
    LinearRegression()
]
adaboost_params={"estimator__n_estimators":[50,100,150,200,75,300,400,350,250,400],
                 "estimator__learning_rate":[1.0,0.1,0.05,0.2,0.5,0.06,0.07,0.3,0.4],
                 "estimator__estimator":base_models}

# %%
randomcv_models=[
    
    ('ab',MultiOutputRegressor(AdaBoostRegressor()),adaboost_params)
]

# %%
##Hyperparameter Tuning
from sklearn.model_selection import RandomizedSearchCV

model_param = {}
for name, model, params in randomcv_models:
    random = RandomizedSearchCV(estimator=model,
                                   param_distributions=params,
                                   n_iter=100,
                                   cv=3,
                                   verbose=2,
                                   n_jobs=-1)
    random.fit(x_train, y_train)
    model_param[name] = random.best_params_

for model_name in model_param:
    print(f"---------------- Best Params for {model_name} -------------------")
    print(model_param[model_name])
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.3, estimator__n_estimators=150; total time=   0.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.3, estimator__n_estimators=150; total time=   0.3s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.3, estimator__n_estimators=150; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=250; total time=   2.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.4, estimator__n_estimators=250; total time=   2.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.4, estimator__n_estimators=250; total time=   2.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.4, estimator__n_estimators=250; total time=   2.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.3, estimator__n_estimators=250; total time=   2.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.3, estimator__n_estimators=250; total time=   2.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=250; total time=   2.8s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=250; total time=   2.8s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.3, estimator__n_estimators=250; total time=   2.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.5, estimator__n_estimators=400; total time=   4.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=1.0, estimator__n_estimators=350; total time=   2.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.5, estimator__n_estimators=400; total time=   4.6s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.3, estimator__n_estimators=350; total time=   0.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.5, estimator__n_estimators=400; total time=   4.7s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.3, estimator__n_estimators=350; total time=   0.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=50; total time=   0.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=1.0, estimator__n_estimators=350; total time=   2.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=1.0, estimator__n_estimators=350; total time=   3.0s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=50; total time=   0.6s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.3, estimator__n_estimators=250; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.06, estimator__n_estimators=400; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=50; total time=   0.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.05, estimator__n_estimators=300; total time=   2.8s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.05, estimator__n_estimators=300; total time=   2.9s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.3, estimator__n_estimators=250; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.3, estimator__n_estimators=250; total time=   0.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.05, estimator__n_estimators=300; total time=   2.9s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.06, estimator__n_estimators=400; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.5, estimator__n_estimators=400; total time=   3.4s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.06, estimator__n_estimators=400; total time=   0.5s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.2, estimator__n_estimators=350; total time=   0.1s[CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.5, estimator__n_estimators=400; total time=   3.4s
#
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.5, estimator__n_estimators=400; total time=   3.4s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.2, estimator__n_estimators=350; total time=   0.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=75; total time=   0.6s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.2, estimator__n_estimators=350; total time=   0.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.1, estimator__n_estimators=50; total time=   0.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.1, estimator__n_estimators=50; total time=   0.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=75; total time=   0.5s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.1, estimator__n_estimators=50; total time=   0.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.05, estimator__n_estimators=50; total time=   0.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=75; total time=   0.4s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.05, estimator__n_estimators=50; total time=   0.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.05, estimator__n_estimators=50; total time=   0.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.1, estimator__n_estimators=400; total time=   2.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.1, estimator__n_estimators=400; total time=   2.6s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.3, estimator__n_estimators=350; total time=   0.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.07, estimator__n_estimators=300; total time=   1.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=250; total time=   1.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=250; total time=   1.7s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=300; total time=   1.7s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.06, estimator__n_estimators=400; total time=   2.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.2, estimator__n_estimators=100; total time=   0.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=300; total time=   1.8s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.06, estimator__n_estimators=400; total time=   2.5s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.2, estimator__n_estimators=400; total time=   0.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=1.0, estimator__n_estimators=300; total time=   1.7s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.2, estimator__n_estimators=400; total time=   0.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=1.0, estimator__n_estimators=300; total time=   1.8s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.2, estimator__n_estimators=400; total time=   0.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.2, estimator__n_estimators=100; total time=   0.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=250; total time=   1.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.07, estimator__n_estimators=300; total time=   1.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.3, estimator__n_estimators=400; total time=   2.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.1, estimator__n_estimators=400; total time=   2.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=300; total time=   1.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.3, estimator__n_estimators=400; total time=   2.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.07, estimator__n_estimators=300; total time=   1.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.4, estimator__n_estimators=300; total time=   1.7s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.2, estimator__n_estimators=100; total time=   0.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.4, estimator__n_estimators=300; total time=   1.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.06, estimator__n_estimators=400; total time=   2.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.4, estimator__n_estimators=300; total time=   1.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=1.0, estimator__n_estimators=300; total time=   1.7s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.1, estimator__n_estimators=250; total time=   0.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.1, estimator__n_estimators=250; total time=   0.3s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.4, estimator__n_estimators=150; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.1, estimator__n_estimators=250; total time=   0.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.4, estimator__n_estimators=150; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.4, estimator__n_estimators=150; total time=   0.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.05, estimator__n_estimators=350; total time=   1.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.05, estimator__n_estimators=350; total time=   2.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.05, estimator__n_estimators=350; total time=   1.9s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.2, estimator__n_estimators=250; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.2, estimator__n_estimators=250; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.2, estimator__n_estimators=250; total time=   0.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.1, estimator__n_estimators=250; total time=   1.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.3, estimator__n_estimators=400; total time=   2.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.1, estimator__n_estimators=250; total time=   1.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=1.0, estimator__n_estimators=400; total time=   2.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.1, estimator__n_estimators=250; total time=   1.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=1.0, estimator__n_estimators=300; total time=   1.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.3, estimator__n_estimators=150; total time=   0.8s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=1.0, estimator__n_estimators=400; total time=   2.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.3, estimator__n_estimators=150; total time=   0.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=1.0, estimator__n_estimators=400; total time=   2.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=1.0, estimator__n_estimators=300; total time=   1.7s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=1.0, estimator__n_estimators=300; total time=   1.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.3, estimator__n_estimators=150; total time=   1.0s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.2, estimator__n_estimators=200; total time=   1.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.2, estimator__n_estimators=200; total time=   1.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.2, estimator__n_estimators=200; total time=   1.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=1.0, estimator__n_estimators=150; total time=   0.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.3, estimator__n_estimators=50; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.3, estimator__n_estimators=50; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.3, estimator__n_estimators=50; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=1.0, estimator__n_estimators=150; total time=   1.0s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=1.0, estimator__n_estimators=150; total time=   1.0s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.05, estimator__n_estimators=100; total time=   0.7s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.05, estimator__n_estimators=100; total time=   0.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.5, estimator__n_estimators=150; total time=   0.8s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.07, estimator__n_estimators=400; total time=   2.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.5, estimator__n_estimators=150; total time=   0.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.07, estimator__n_estimators=400; total time=   2.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.05, estimator__n_estimators=100; total time=   0.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.07, estimator__n_estimators=400; total time=   2.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.5, estimator__n_estimators=150; total time=   1.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.2, estimator__n_estimators=350; total time=   2.0s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.2, estimator__n_estimators=350; total time=   2.0s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.06, estimator__n_estimators=400; total time=   0.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.06, estimator__n_estimators=400; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.2, estimator__n_estimators=350; total time=   2.3s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.06, estimator__n_estimators=400; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.5, estimator__n_estimators=200; total time=   1.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.5, estimator__n_estimators=200; total time=   1.0s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.05, estimator__n_estimators=350; total time=   0.3s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.05, estimator__n_estimators=350; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.5, estimator__n_estimators=200; total time=   1.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.05, estimator__n_estimators=350; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=75; total time=   0.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=75; total time=   0.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=75; total time=   0.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.05, estimator__n_estimators=400; total time=   2.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=350; total time=   1.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.05, estimator__n_estimators=400; total time=   2.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.06, estimator__n_estimators=100; total time=   0.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.06, estimator__n_estimators=100; total time=   0.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.06, estimator__n_estimators=100; total time=   0.7s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=350; total time=   2.0s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=350; total time=   2.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.05, estimator__n_estimators=400; total time=   2.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=150; total time=   0.8s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.3, estimator__n_estimators=100; total time=   0.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.3, estimator__n_estimators=100; total time=   0.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=150; total time=   0.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=150; total time=   0.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.3, estimator__n_estimators=100; total time=   0.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=200; total time=   1.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.05, estimator__n_estimators=100; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=200; total time=   1.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.05, estimator__n_estimators=100; total time=   0.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=200; total time=   1.3s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.05, estimator__n_estimators=100; total time=   0.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=400; total time=   2.4s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.1, estimator__n_estimators=200; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=400; total time=   2.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=400; total time=   2.5s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.1, estimator__n_estimators=200; total time=   0.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.1, estimator__n_estimators=200; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.4, estimator__n_estimators=350; total time=   1.8s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.4, estimator__n_estimators=350; total time=   1.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.4, estimator__n_estimators=350; total time=   1.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=300; total time=   1.7s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=300; total time=   1.7s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=300; total time=   1.8s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.2, estimator__n_estimators=250; total time=   1.5s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.07, estimator__n_estimators=400; total time=   0.3s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.07, estimator__n_estimators=400; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.2, estimator__n_estimators=250; total time=   1.4s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.07, estimator__n_estimators=400; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.2, estimator__n_estimators=250; total time=   1.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=350; total time=   2.0s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.07, estimator__n_estimators=75; total time=   0.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.07, estimator__n_estimators=75; total time=   0.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.07, estimator__n_estimators=75; total time=   0.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=350; total time=   2.0s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=350; total time=   2.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.1, estimator__n_estimators=150; total time=   0.8s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.1, estimator__n_estimators=150; total time=   0.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.1, estimator__n_estimators=150; total time=   1.0s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.5, estimator__n_estimators=50; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.5, estimator__n_estimators=50; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.3, estimator__n_estimators=350; total time=   1.0s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.5, estimator__n_estimators=50; total time=   0.3s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.1, estimator__n_estimators=75; total time=   0.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=400; total time=   2.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=100; total time=   0.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=100; total time=   0.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=100; total time=   0.6s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.1, estimator__n_estimators=75; total time=   0.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=400; total time=   2.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=400; total time=   2.5s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.1, estimator__n_estimators=75; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.3, estimator__n_estimators=400; total time=   1.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.2, estimator__n_estimators=75; total time=   0.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.3, estimator__n_estimators=350; total time=   2.0s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.2, estimator__n_estimators=75; total time=   0.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.2, estimator__n_estimators=75; total time=   0.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.3, estimator__n_estimators=350; total time=   2.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.06, estimator__n_estimators=300; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.3, estimator__n_estimators=400; total time=   2.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.3, estimator__n_estimators=400; total time=   2.4s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.06, estimator__n_estimators=300; total time=   0.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.06, estimator__n_estimators=50; total time=   0.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.06, estimator__n_estimators=50; total time=   0.3s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.06, estimator__n_estimators=300; total time=   0.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.06, estimator__n_estimators=50; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=50; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=50; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.05, estimator__n_estimators=300; total time=   1.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=50; total time=   0.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.05, estimator__n_estimators=300; total time=   1.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.05, estimator__n_estimators=300; total time=   1.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=400; total time=   1.8s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.5, estimator__n_estimators=350; total time=   0.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.06, estimator__n_estimators=200; total time=   1.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.06, estimator__n_estimators=200; total time=   1.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.5, estimator__n_estimators=350; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=1.0, estimator__n_estimators=400; total time=   0.0s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=1.0, estimator__n_estimators=400; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.5, estimator__n_estimators=350; total time=   0.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.06, estimator__n_estimators=200; total time=   1.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=1.0, estimator__n_estimators=400; total time=   0.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.2, estimator__n_estimators=150; total time=   0.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.2, estimator__n_estimators=150; total time=   0.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.2, estimator__n_estimators=150; total time=   0.9s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.5, estimator__n_estimators=200; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.2, estimator__n_estimators=150; total time=   0.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.2, estimator__n_estimators=150; total time=   0.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.2, estimator__n_estimators=150; total time=   0.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.5, estimator__n_estimators=200; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.5, estimator__n_estimators=200; total time=   0.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=400; total time=   2.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.05, estimator__n_estimators=100; total time=   0.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.05, estimator__n_estimators=100; total time=   0.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.05, estimator__n_estimators=100; total time=   0.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.1, estimator__n_estimators=400; total time=   2.8s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.5, estimator__n_estimators=300; total time=   1.7s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.5, estimator__n_estimators=300; total time=   1.6s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.5, estimator__n_estimators=300; total time=   1.7s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.06, estimator__n_estimators=300; total time=   1.6s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.06, estimator__n_estimators=50; total time=   0.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.2, estimator__n_estimators=250; total time=   1.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.06, estimator__n_estimators=300; total time=   1.7s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.06, estimator__n_estimators=50; total time=   0.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.2, estimator__n_estimators=250; total time=   1.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.2, estimator__n_estimators=250; total time=   1.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.06, estimator__n_estimators=400; total time=   2.3s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.06, estimator__n_estimators=50; total time=   0.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.06, estimator__n_estimators=300; total time=   1.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.06, estimator__n_estimators=400; total time=   2.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.06, estimator__n_estimators=400; total time=   2.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.2, estimator__n_estimators=50; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.2, estimator__n_estimators=50; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.3, estimator__n_estimators=75; total time=   0.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.3, estimator__n_estimators=75; total time=   0.5s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.3, estimator__n_estimators=400; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.3, estimator__n_estimators=400; total time=   0.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.3, estimator__n_estimators=75; total time=   0.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.2, estimator__n_estimators=50; total time=   0.3s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.3, estimator__n_estimators=400; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.3, estimator__n_estimators=200; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.3, estimator__n_estimators=200; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.3, estimator__n_estimators=200; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.1, estimator__n_estimators=150; total time=   0.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.1, estimator__n_estimators=150; total time=   0.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=1.0, estimator__n_estimators=75; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=1.0, estimator__n_estimators=75; total time=   0.0s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.1, estimator__n_estimators=150; total time=   0.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=1.0, estimator__n_estimators=75; total time=   0.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.06, estimator__n_estimators=400; total time=   2.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.06, estimator__n_estimators=400; total time=   2.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.06, estimator__n_estimators=400; total time=   2.3s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.06, estimator__n_estimators=200; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=250; total time=   1.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.5, estimator__n_estimators=150; total time=   0.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.5, estimator__n_estimators=150; total time=   0.9s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=250; total time=   1.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=250; total time=   1.5s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.5, estimator__n_estimators=150; total time=   1.0s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.2, estimator__n_estimators=50; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.2, estimator__n_estimators=50; total time=   0.2s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.2, estimator__n_estimators=50; total time=   0.1s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.06, estimator__n_estimators=200; total time=   0.3s
# [CV] END estimator__estimator=LinearRegression(), estimator__learning_rate=0.06, estimator__n_estimators=200; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.4, estimator__n_estimators=150; total time=   0.8s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.4, estimator__n_estimators=150; total time=   0.8s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=3), estimator__learning_rate=0.4, estimator__n_estimators=150; total time=   0.8s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=50; total time=   0.2s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=50; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.07, estimator__n_estimators=50; total time=   0.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.1, estimator__n_estimators=350; total time=   1.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.1, estimator__n_estimators=350; total time=   1.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=300; total time=   1.1s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.1, estimator__n_estimators=350; total time=   1.3s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=300; total time=   1.4s
# [CV] END estimator__estimator=DecisionTreeRegressor(max_depth=5), estimator__learning_rate=0.4, estimator__n_estimators=300; total time=   1.3s
# ---------------- Best Params for ab -------------------
# {'estimator__n_estimators': 400, 'estimator__learning_rate': 0.3, 'estimator__estimator': LinearRegression()}

# %%
## Retraining the models with best parameters
models = {
   
     "adaboost regressor":MultiOutputRegressor(AdaBoostRegressor(n_estimators=250, learning_rate= 0.2, estimator =LinearRegression())),
    
    
}
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(x_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)

    model_train_mae , model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)

    model_test_mae , model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)
    
    print(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- R2 Score: {:.4f}".format(model_train_r2))

    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- R2 Score: {:.4f}".format(model_test_r2))
    
    print('='*35)
    print('\n')
# Out:
# adaboost regressor
# Model performance for Training set
# - Root Mean Squared Error: 1.1676
# - Mean Absolute Error: 0.6795
# - R2 Score: 0.8337
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 1.1675
# - Mean Absolute Error: 0.6766
# - R2 Score: 0.8222
# ===================================

# %%
y.head()
# Out:
#    supplier_rank  supplier_score
# 0            1.0       94.148153
# 1            2.0       88.189929
# 2            3.0       87.199128
# 3            4.0       86.214753
# 4            5.0       76.833344

# %%
pd.DataFrame(y_train_pred)
# Out:
#             0          1
# 0    4.619096  87.072216
# 1    4.640443  86.917314
# 2    2.914251  91.112827
# 3    5.309815  84.473256
# 4    3.402036  89.036084
# ..        ...        ...
# 126  8.014695  78.647604
# 127  1.716234  93.923920
# 128  4.919291  87.673319
# 129  3.230936  92.113082
# 130  6.284278  83.278193
#
# [131 rows x 2 columns]

# %%
pd.DataFrame(y_test_pred)
# Out:
#             0          1
# 0    3.986544  87.313076
# 1    2.992379  92.625193
# 2    5.501743  86.276932
# 3    3.804268  89.088965
# 4    3.792799  88.777034
# 5    1.115346  96.118069
# 6    5.403983  86.128922
# 7    7.640633  78.936532
# 8    3.393077  88.585941
# 9    7.547614  79.485016
# 10   7.879227  81.880676
# 11   5.335722  86.339452
# 12   2.445450  93.403877
# 13   4.678362  86.448587
# 14   4.003107  88.983091
# 15   4.050950  88.822231
# 16   7.912875  77.127497
# 17   1.967682  97.680435
# 18   9.060318  75.512394
# 19   2.989465  93.627511
# 20   5.518587  84.104523
# 21   8.551159  79.434525
# 22   5.378738  85.628290
# 23   5.243162  84.943187
# 24   8.932000  76.450802
# 25   2.548163  95.261262
# 26   9.074868  74.319736
# 27   5.351961  85.537218
# 28   4.273079  88.881145
# 29   7.539283  80.122411
# 30   7.560362  79.179747
# 31   6.628344  79.998151
# 32   4.249080  87.094211
# 33   2.691832  95.253268
# 34   2.426191  93.271862
# 35   3.061578  91.308535
# 36   3.885704  89.360769
# 37   2.959874  88.969118
# 38   6.649703  82.741434
# 39   1.773198  95.541061
# 40   7.306255  80.030013
# 41   6.949394  79.624734
# 42   5.813986  83.959235
# 43   6.183047  84.286868
# 44   8.874030  76.446521
# 45   7.810418  79.777912
# 46   2.016234  93.948631
# 47   4.899771  86.862619
# 48   9.689811  74.478441
# 49   1.956320  95.545506
# 50  10.278870  74.290000
# 51   3.693882  89.606332
# 52   7.387495  80.094623
# 53   7.190534  79.834496
# 54   7.027230  80.432697
# 55   5.998685  81.980008
# 56   7.518753  79.735450

# %%
y_test_pred.max(),y_test_pred.min()
# Out:
# (np.float64(97.6804346818141), np.float64(1.1153457833053952))

# %%
df.head()
# Out:
#   product_id product_name supplier_id            supplier_name   region  \
# 0         P1   Dawat Rice          S8          Martin-Mcdowell   Mumbai
# 1         P1   Dawat Rice          S5           Nelson-Ramirez   Mumbai
# 2         P1   Dawat Rice          S3  Bell, Gardner and Brown  Kolkata
# 3         P1   Dawat Rice          S3  Bell, Gardner and Brown   Mumbai
# 4         P1   Dawat Rice          S9             Thornton Ltd  Kolkata
#
#   purchase_date  units_purchased  unit_cost  total_cost  delivery_time_days  \
# 0    2025-01-11              971      16.55    16070.05                   6
# 1    2025-03-14              689      38.80    26733.20                   7
# 2    2025-04-29              814      37.38    30427.32                   7
# 3    2024-12-30              990      23.38    23146.20                   3
# 4    2025-06-02              406      64.58    26219.48                   2
#
#    qc_pass_rate  customer_rating_avg  damaged_on_arrival  complaint_count  \
# 0          0.97                 4.41                0.00                2
# 1          0.98                 3.78                0.00                6
# 2          0.93                 3.86                0.01                5
# 3          0.91                 3.17                0.05                9
# 4          0.85                 3.20                0.03                2
#
#    units_returned  return_rate  supplier_score  supplier_rank
# 0              62        0.064       94.148153            1.0
# 1              25        0.036       88.189929            2.0
# 2              35        0.043       87.199128            3.0
# 3              84        0.085       86.214753            4.0
# 4              16        0.039       76.833344            5.0

# %%
x.max()
# Out:
# units_purchased          997.00
# unit_cost                 96.73
# total_cost             94698.67
# delivery_time_days        10.00
# qc_pass_rate               1.00
# customer_rating_avg        4.98
# damaged_on_arrival         0.05
# complaint_count           10.00
# units_returned            87.00
# return_rate                0.10
# dtype: float64

# %%
y.max(
    
)
# Out:
# supplier_rank     10.000000
# supplier_score    97.680435
# dtype: float64

# %%
y.min()
# Out:
# supplier_rank      1.000000
# supplier_score    71.544992
# dtype: float64

# %%
final_model = MultiOutputRegressor(
    AdaBoostRegressor(
        estimator=LinearRegression(), 
        n_estimators=250, 
        learning_rate=0.2
    )
)
final_model.fit(x, y)

from sklearn.metrics import mean_squared_error, r2_score

y_pred = final_model.predict(x_test)

print("R2:", r2_score(y_test, y_pred, multioutput='raw_values'))
print("MSE:", mean_squared_error(y_test, y_pred, multioutput='raw_values'))

import joblib
joblib.dump(final_model, "multioutput_model.pkl")
# Out:
# R2: [0.71184761 1.        ]
# MSE: [2.20907962e+00 4.60127010e-25]
# ['multioutput_model.pkl']

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import joblib
df_suppliers=pd.read_csv('best_brand_suppliers_per_product.csv')
# Clean column names
df = df_suppliers.copy()
df.columns = df.columns.str.strip().str.replace(" ", "_")

# Features used for model prediction (assumed)
feature_cols = [
    "units_purchased", "unit_cost", "delivery_time_days", "qc_pass_rate",
    "customer_rating_avg", "damaged_on_arrival", "complaint_count", "return_rate"
]

# Load your trained model (assumed saved as `multioutput_model.pkl`)
# We'll mock a placeholder if model isn't available
model_path = "/home/prateekpathak/Downloads/python1/Walmart_manufacturer/multioutput_model.pkl"

try:
    model = joblib.load(model_path)
except:
    model = None  # Placeholder in case model isn't uploaded yet

# Create prediction function
def get_supplier_predictions(product_name, region):
    # Filter known data
    match = df[(df["product_name"].str.lower() == product_name.lower()) &
               (df["region"].str.lower() == region.lower())]

    if not match.empty:
        return match[["supplier_id", "supplier_name", "region", "supplier_score","delivery_time_days","return_rate"]]

    # If new product/region combo, average over similar product or region
    sample_input = df[df["product_name"].str.lower() == product_name.lower()]
    if sample_input.empty:
        sample_input = df[df["region"].str.lower() == region.lower()]
    if sample_input.empty:
        sample_input = df  # fallback to full data

    # Take average feature values
    mean_features = sample_input[feature_cols].mean().values.reshape(1, -1)

    # Scale
    scaler = MinMaxScaler()
    x_scaled = scaler.fit_transform(df[feature_cols])
    mean_scaled = scaler.transform(mean_features)

    # Predict using model
    if model:
        score, rank = model.predict(mean_scaled)[0]
        return pd.DataFrame([{
            "supplier_id": "Unknown",
            "supplier_name": "New Supplier",
            "region": region,
            "supplier_score": round(score, 2),
            "supplier_rank": int(round(rank))
        }])
    else:
        return pd.DataFrame([{
            "supplier_id": "Unknown",
            "supplier_name": "New Supplier",
            "region": region,
            "supplier_score": "enter valid region",  # Default/fallback
            "supplier_rank": "enter valid rank"
        }])

# %%
df.head(20)
# Out:
#    product_id  product_name supplier_id                  supplier_name  \
# 0          P1    Dawat Rice          S8                Martin-Mcdowell
# 1          P1    Dawat Rice          S5                 Nelson-Ramirez
# 2          P1    Dawat Rice          S3        Bell, Gardner and Brown
# 3          P1    Dawat Rice          S3        Bell, Gardner and Brown
# 4          P1    Dawat Rice          S9                   Thornton Ltd
# 5          P1    Dawat Rice          S1                     Bass Group
# 6         P10      Tata Tea         S10  Murphy, Aguilar and Zimmerman
# 7         P10      Tata Tea          S2                    Flores-Cook
# 8         P10      Tata Tea          S7                 Thompson Group
# 9         P10      Tata Tea          S4                    Bond-Adkins
# 10        P10      Tata Tea          S6         Terry, Smith and Weber
# 11        P10      Tata Tea          S1                     Bass Group
# 12        P11  Oreo Biscuit          S7                 Thompson Group
# 13        P11  Oreo Biscuit          S7                 Thompson Group
# 14        P11  Oreo Biscuit         S10  Murphy, Aguilar and Zimmerman
# 15        P11  Oreo Biscuit          S9                   Thornton Ltd
# 16        P11  Oreo Biscuit          S8                Martin-Mcdowell
# 17        P11  Oreo Biscuit         S10  Murphy, Aguilar and Zimmerman
# 18        P11  Oreo Biscuit          S7                 Thompson Group
# 19        P11  Oreo Biscuit          S3        Bell, Gardner and Brown
#
#        region purchase_date  units_purchased  unit_cost  total_cost  \
# 0      Mumbai    2025-01-11              971      16.55    16070.05
# 1      Mumbai    2025-03-14              689      38.80    26733.20
# 2     Kolkata    2025-04-29              814      37.38    30427.32
# 3      Mumbai    2024-12-30              990      23.38    23146.20
# 4     Kolkata    2025-06-02              406      64.58    26219.48
# 5   Hyderabad    2024-10-02              432      81.03    35004.96
# 6   Hyderabad    2024-11-24              477      11.02     5256.54
# 7   Ahmedabad    2025-01-28              514      36.38    18699.32
# 8   Bengaluru    2025-04-20              813      43.10    35040.30
# 9   Ahmedabad    2024-12-11              378      54.25    20506.50
# 10    Kolkata    2025-04-08              206      76.38    15734.28
# 11    Kolkata    2024-07-07              949      83.54    79279.46
# 12  Delhi NCR    2024-07-02              420      21.22     8912.40
# 13     Mumbai    2024-08-10              921      11.39    10490.19
# 14  Ahmedabad    2024-07-22              710      13.29     9435.90
# 15  Hyderabad    2025-05-28              373      20.86     7780.78
# 16  Hyderabad    2025-04-06              822      26.61    21873.42
# 17    Kolkata    2025-05-06              153      35.98     5504.94
# 18  Bengaluru    2025-01-24              720      42.35    30492.00
# 19  Delhi NCR    2025-03-10              786      40.08    31502.88
#
#     delivery_time_days  qc_pass_rate  customer_rating_avg  damaged_on_arrival  \
# 0                    6          0.97                 4.41                0.00
# 1                    7          0.98                 3.78                0.00
# 2                    7          0.93                 3.86                0.01
# 3                    3          0.91                 3.17                0.05
# 4                    2          0.85                 3.20                0.03
# 5                    1          0.92                 3.17                0.03
# 6                    8          0.92                 3.11                0.01
# 7                    1          0.98                 3.03                0.00
# 8                    9          0.94                 4.27                0.03
# 9                    6          0.92                 3.35                0.02
# 10                  10          0.92                 3.45                0.02
# 11                   7          0.89                 3.34                0.03
# 12                   5          0.99                 4.74                0.03
# 13                   4          0.99                 3.86                0.05
# 14                   2          0.92                 4.13                0.00
# 15                   1          0.92                 3.41                0.02
# 16                   7          0.88                 3.74                0.02
# 17                   6          0.90                 4.44                0.01
# 18                   9          0.89                 4.62                0.04
# 19                   9          0.97                 3.21                0.00
#
#     complaint_count  units_returned  return_rate  supplier_score  \
# 0                 2              62        0.064       94.148153
# 1                 6              25        0.036       88.189929
# 2                 5              35        0.043       87.199128
# 3                 9              84        0.085       86.214753
# 4                 2              16        0.039       76.833344
# 5                 4              22        0.051       74.319736
# 6                 8              33        0.069       90.030175
# 7                 5              10        0.019       87.010959
# 8                10              62        0.076       86.163059
# 9                 5              34        0.090       79.998151
# 10                8               6        0.029       76.997747
# 11                4               1        0.001       74.997842
# 12                5               9        0.021       95.545506
# 13                4              20        0.022       94.954398
# 14                0              19        0.027       93.923920
# 15                4              19        0.051       89.088965
# 16                6              19        0.023       88.585941
# 17                1              10        0.065       87.853691
# 18                1              49        0.068       86.276932
# 19                1              54        0.069       84.943187
#
#     supplier_rank
# 0             1.0
# 1             2.0
# 2             3.0
# 3             4.0
# 4             5.0
# 5             6.0
# 6             1.0
# 7             2.0
# 8             3.0
# 9             4.0
# 10            5.0
# 11            6.0
# 12            1.0
# 13            2.0
# 14            3.0
# 15            4.0
# 16            5.0
# 17            6.0
# 18            7.0
# 19            8.0

# %%
get_supplier_predictions('Parle','Kolkata')
# Out:
#   supplier_id supplier_name   region      supplier_score     supplier_rank
# 0     Unknown  New Supplier  Kolkata  enter valid region  enter valid rank

# %%
print(x.columns)
# Out:
# Index(['units_purchased', 'unit_cost', 'total_cost', 'delivery_time_days',
#        'qc_pass_rate', 'customer_rating_avg', 'damaged_on_arrival',
#        'complaint_count', 'units_returned', 'return_rate'],
#       dtype='object')
