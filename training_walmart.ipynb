# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
# %matplotlib inline

# %%
df=pd.read_csv("walmart_dataset_noisy.csv")

# %%
df.head()
# Out:
#         GST_Number  Product_Quality_Score  Delivery_Timeliness  \
# 0  05DFSEE4613E1Z1              68.727006            64.124955
# 1  33QTXKU6195S1Z2              97.535715            96.102116
# 2  21EBZNZ6857G1Z3              86.599697            80.210095
# 3  26TXCVD6236F1Z4              79.932924            93.058299
# 4  14IQVJS5755K1Z5              57.800932            72.801984
#
#    Fulfillment_Rate  Return_Rate  Dispute_Count  Cost_Effectiveness  \
# 0         91.217159    15.165264              1           50.451923
# 1         74.576171     0.491738              1           67.851467
# 2         87.288651     0.442471              0           96.309703
# 3         88.201451     6.472204              1           61.433839
# 4         82.723920     9.772864              2           81.718184
#
#    Communication_Latency  Compliance_Score  Sustainability_Score  \
# 0               3.734328         93.877792             50.810104
# ...

# %%
x=df.drop(["Retain_Manufacturer","GST_Number","Sustainability_Score","Retain_Manufacturer_Noisy"],axis=1)

# %%
x
# Out:
#      Product_Quality_Score  Delivery_Timeliness  Fulfillment_Rate  \
# 0                68.727006            64.124955         91.217159
# 1                97.535715            96.102116         74.576171
# 2                86.599697            80.210095         87.288651
# 3                79.932924            93.058299         88.201451
# 4                57.800932            72.801984         82.723920
# ..                     ...                  ...               ...
# 395              96.537866            94.884956         96.146104
# 396              92.920638            97.284731         99.204669
# 397              71.449701            82.605327         99.066336
# 398              87.543553            87.866033         92.489555
# 399              87.727144            96.899975         73.902587
#
#      Return_Rate  Dispute_Count  Cost_Effectiveness  Communication_Latency  \
# 0      15.165264              1           50.451923               3.734328
# ...

# %%
from sklearn.preprocessing import StandardScaler
StandardScaler=StandardScaler()

# %%
x_scaled_df=StandardScaler.fit_transform(x)

# %%
x_scaled_df
# Out:
# array([[-0.40782246, -1.35158561,  0.68705015, ...,  0.77435561,
#          1.07919676, -0.5850924 ],
#        [ 1.55603597,  1.37282681, -1.18401623, ...,  0.82250534,
#         -1.05925591, -1.13228345],
#        [ 0.81053949,  0.01884733,  0.24533961, ...,  0.05604018,
#          0.65494701, -1.40419681],
#        ...,
#        [-0.22221927,  0.22291801,  1.56958974, ..., -1.45215071,
#         -0.76747647,  1.48705836],
#        [ 0.87488115,  0.67112326,  0.83011481, ...,  0.20354606,
#          1.38976585,  1.3985845 ],
#        [ 0.8873963 ,  1.44080335, -1.25975215, ...,  1.21978641,
#          1.42284774,  1.08892452]])

# %%
pd.DataFrame(x_scaled_df,columns=x.columns)
# Out:
#      Product_Quality_Score  Delivery_Timeliness  Fulfillment_Rate  \
# 0                -0.407822            -1.351586          0.687050
# 1                 1.556036             1.372827         -1.184016
# 2                 0.810539             0.018847          0.245340
# 3                 0.356073             1.113498          0.347972
# 4                -1.152641            -0.612314         -0.267906
# ..                     ...                  ...               ...
# 395               1.488014             1.269126          1.241247
# 396               1.241431             1.473584          1.585144
# 397              -0.222219             0.222918          1.569590
# 398               0.874881             0.671123          0.830115
# 399               0.887396             1.440803         -1.259752
#
#      Return_Rate  Dispute_Count  Cost_Effectiveness  Communication_Latency  \
# 0       0.905392      -0.728444           -1.707136               0.774356
# ...

# %%
y=df["Retain_Manufacturer"] = (
    (0.25 * df["Product_Quality_Score"]) +
    (0.20 * df["Delivery_Timeliness"]) +
    (0.15 * df["Fulfillment_Rate"]) -
    (0.10 * df["Return_Rate"]) -
    (0.08 * df["Dispute_Count"]) +
    (0.07 * df["Cost_Effectiveness"]) -
    (0.05 * df["Communication_Latency"]) +
    (0.08 * df["Compliance_Score"]) +
    (0.02*  df["Yearly_Performance_Trend"])
    
)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.30)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
##Create a Function to Evaluate Model
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
print("x_train:", x_train.shape)
print("y_train:", y_train.shape)
print("x_test:", x_test.shape)
print("y_test:", y_test.shape)
# Out:
# x_train: (280, 9)
# y_train: (280,)
# x_test: (120, 9)
# y_test: (120,)

# %%
## Beginning Model Training
models = {
    "Linear Regression": LinearRegression(),
    "Lasso": Lasso(),
    "Ridge": Ridge(),
    "K-Neighbors Regressor": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "Adaboost Regressor":AdaBoostRegressor(),
    "Graident BoostRegressor":GradientBoostingRegressor()
   
}

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(x_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)
    
    # Evaluate Train and Test dataset
    model_train_mae , model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)

    model_test_mae , model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    
    print(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- R2 Score: {:.4f}".format(model_train_r2))

    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- R2 Score: {:.4f}".format(model_test_r2))
    
    print('='*35)
    print('\n')
# Out:
# Linear Regression
# Model performance for Training set
# - Root Mean Squared Error: 0.0000
# - Mean Absolute Error: 0.0000
# - R2 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.0000
# - Mean Absolute Error: 0.0000
# - R2 Score: 1.0000
# ...
#
#
# Lasso
# Model performance for Training set
# - Root Mean Squared Error: 0.3124
# - Mean Absolute Error: 0.2554
# - R2 Score: 0.9961
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.3071
# - Mean Absolute Error: 0.2458
# - R2 Score: 0.9960
# ...
#
#
# Ridge
# Model performance for Training set
# - Root Mean Squared Error: 0.0003
# - Mean Absolute Error: 0.0002
# - R2 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.0003
# - Mean Absolute Error: 0.0002
# - R2 Score: 1.0000
# ...
#
#
# K-Neighbors Regressor
# Model performance for Training set
# - Root Mean Squared Error: 1.1376
# ...

# %%
decision_params={"max_depth":[5,10,15,8,6],
                 "min_samples_split":[10,5,2,8,20],
                 "max_features":['sqrt','log2',None,'auto'],
                 'min_samples_leaf':[5,2,1,4,10]}
adaboost_params={"n_estimators":[50,100,150,200,75],
                 "learning_rate":[1.0,0.1,0.05,0.2,0.5],
                 "loss":['linear','square','exponensial']}

# %%
randomcv_models=[
    ("dt",DecisionTreeRegressor(),decision_params),
    ('ab',AdaBoostRegressor(),adaboost_params)
]

# %%
##Hyperparameter Tuning
from sklearn.model_selection import RandomizedSearchCV

model_param = {}
for name, model, params in randomcv_models:
    random = RandomizedSearchCV(estimator=model,
                                   param_distributions=params,
                                   n_iter=100,
                                   cv=3,
                                   verbose=2,
                                   n_jobs=-1)
    random.fit(x_train, y_train)
    model_param[name] = random.best_params_

for model_name in model_param:
    print(f"---------------- Best Params for {model_name} -------------------")
    print(model_param[model_name])
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=20; total time=   0.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# ...

# %%
## Retraining the models with best parameters
models = {
    "decision tree regressor": DecisionTreeRegressor(min_samples_split=8,min_samples_leaf=5, max_features= None, max_depth= 10),
     "adaboost regressor":AdaBoostRegressor(n_estimators =200, loss='square',learning_rate=1.0)
    
}
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(x_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)

    model_train_mae , model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)

    model_test_mae , model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)
    
    print(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- R2 Score: {:.4f}".format(model_train_r2))

    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- R2 Score: {:.4f}".format(model_test_r2))
    
    print('='*35)
    print('\n')
# Out:
# decision tree regressor
# Model performance for Training set
# - Root Mean Squared Error: 1.1150
# - Mean Absolute Error: 0.8384
# - R2 Score: 0.9499
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 2.3834
# - Mean Absolute Error: 1.9378
# - R2 Score: 0.7599
# ...
#
#
# adaboost regressor
# Model performance for Training set
# - Root Mean Squared Error: 1.0996
# - Mean Absolute Error: 0.9151
# - R2 Score: 0.9513
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 1.5768
# - Mean Absolute Error: 1.2453
# - R2 Score: 0.8949
# ...

# %%
y.head()
# Out:
# 0    52.882080
# 1    65.112545
# 2    64.395818
# 3    61.648849
# 4    52.121847
# dtype: float64

# %%
pd.DataFrame(y_train_pred)
# Out:
#              0
# 0    57.518702
# 1    55.167394
# 2    57.188153
# 3    53.341340
# 4    55.893919
# ..         ...
# 275  56.296681
# 276  59.868060
# 277  59.497388
# 278  61.410979
# 279  52.622536
#
# [280 rows x 1 columns]

# %%
pd.DataFrame(y_test_pred)
# Out:
#              0
# 0    55.883584
# 1    63.474326
# 2    59.403879
# 3    56.290266
# 4    56.273733
# ..         ...
# 115  55.297808
# 116  52.284775
# 117  52.691834
# 118  66.641196
# 119  52.897078
#
# [120 rows x 1 columns]

# %%
df.max()
# Out:
# GST_Number                   37ZWUMI6016U1Z9
# Product_Quality_Score              99.525257
# Delivery_Timeliness                99.988707
# Fulfillment_Rate                   99.938023
# Return_Rate                        19.988275
# Dispute_Count                              7
# Cost_Effectiveness                 99.662751
# Communication_Latency               4.995017
# Compliance_Score                   99.986731
# Sustainability_Score               99.842457
# Yearly_Performance_Trend            9.938988
# Retain_Manufacturer                71.212721
# Retain_Manufacturer_Noisy           0.192637
# dtype: object

# %%
df.head()
# Out:
#         GST_Number  Product_Quality_Score  Delivery_Timeliness  \
# 0  05DFSEE4613E1Z1              68.727006            64.124955
# 1  33QTXKU6195S1Z2              97.535715            96.102116
# 2  21EBZNZ6857G1Z3              86.599697            80.210095
# 3  26TXCVD6236F1Z4              79.932924            93.058299
# 4  14IQVJS5755K1Z5              57.800932            72.801984
#
#    Fulfillment_Rate  Return_Rate  Dispute_Count  Cost_Effectiveness  \
# 0         91.217159    15.165264              1           50.451923
# 1         74.576171     0.491738              1           67.851467
# 2         87.288651     0.442471              0           96.309703
# 3         88.201451     6.472204              1           61.433839
# 4         82.723920     9.772864              2           81.718184
#
#    Communication_Latency  Compliance_Score  Sustainability_Score  \
# 0               3.734328         93.877792             50.810104
# ...

# %%
x.max()
# Out:
# Product_Quality_Score       99.525257
# Delivery_Timeliness         99.988707
# Fulfillment_Rate            99.938023
# Return_Rate                 19.988275
# Dispute_Count                7.000000
# Cost_Effectiveness          99.662751
# Communication_Latency        4.995017
# Compliance_Score            99.986731
# Yearly_Performance_Trend     9.938988
# dtype: float64

# %%
y.max(
    
)
# Out:
# 71.21272097808814
